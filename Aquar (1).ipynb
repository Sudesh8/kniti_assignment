# %%
# installing necessary libraries
# !pip install mmcv-full
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 607.9/607.9 kB 16.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 13.2 MB/s eta 0:00:00
# ...
#   Created wheel for mmcv-full: filename=mmcv_full-1.7.2-cp310-cp310-linux_x86_64.whl size=27457452 sha256=ce8f150198d85a4e07df2425d8243a0a1de7a84a9ab2689bf85482ae2490c1ff
#   Stored in directory: /root/.cache/pip/wheels/4e/10/0a/78fbabe3d28cc25866432d4ecd6c9b124b8f0a6f546974bb7e
# Successfully built mmcv-full
# ...

# %%
# !pip install mmdet
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 51.7 MB/s eta 0:00:00
# ...

# %%
# !pip install mmengine
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 20.5 MB/s eta 0:00:00
# ...

# %%
# Import locale library to handle encoding issues
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install mmcv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 479.1/479.1 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 99, in main
#     with self.main_context():
#   File "/usr/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/command_context.py", line 19, in main_context
#     with self._main_context:
#   File "/usr/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/usr/lib/python3.10/contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
# ...

# %%
from mmdet.apis import init_detector, inference_detector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-11141f4a1d98> in <cell line: 1>()
# ----> 1 from mmdet.apis import init_detector, inference_detector
#       2
#
# ModuleNotFoundError: No module named 'mmdet'

# %%
# While I initially attempted to use MMDetection for this task, I encountered persistent errors that hindered my progress. Given the time constraints and the need for a working solution, I decided to switch to the YOLO framework.

# %%
# Install the ultralytics package, which includes YOLOv8 implementation

# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
# Import YOLO class from the ultralytics library
from ultralytics import YOLO

# %%
# Load the pre-trained YOLOv8 model from the specified weights file
# 'yolov8s.pt' is a pre-trained model file for YOLOv8
model=YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 33.6MB/s]

# %%
# Unzip the dataset archive located in Google Drive into a folder named "train_data"
# The archive 'Aquariumyolov8.zip' contains images for training the model
# !unzip /content/drive/MyDrive/dataset/Aquariumyolov8.zip -d "train_data"
# Out:
# Archive:  /content/drive/MyDrive/dataset/Aquariumyolov8.zip
#  extracting: train_data/README.dataset.txt
#  extracting: train_data/README.roboflow.txt
#  extracting: train_data/data.yaml
#    creating: train_data/test/
#    creating: train_data/test/images/
#  extracting: train_data/test/images/IMG_2289_jpeg_jpg.rf.fe2a7a149e7b11f2313f5a7b30386e85.jpg
#  extracting: train_data/test/images/IMG_2301_jpeg_jpg.rf.2c19ae5efbd1f8611b5578125f001695.jpg
#  extracting: train_data/test/images/IMG_2319_jpeg_jpg.rf.6e20bf97d17b74a8948aa48776c40454.jpg
#  extracting: train_data/test/images/IMG_2347_jpeg_jpg.rf.7c71ac4b9301eb358cd4a832844dedcb.jpg
#  extracting: train_data/test/images/IMG_2354_jpeg_jpg.rf.396e872c7fb0a95e911806986995ee7a.jpg
#  extracting: train_data/test/images/IMG_2371_jpeg_jpg.rf.54505f60b6706da151c164188c305849.jpg
#  extracting: train_data/test/images/IMG_2379_jpeg_jpg.rf.7dc3160c937072d26d4624c6c48e904d.jpg
# ...

# %%
# Install the yolosplitter package, used for splitting YOLO datasets into training, validation, and test sets
# !pip install yolosplitter

# %%
# Import YoloSplitter class from yolosplitter package
from yolosplitter import YoloSplitter

# %%
# Initialize YoloSplitter object for dataset splitting
ys=YoloSplitter()

# %%
# Split the dataset into training and validation sets with the specified ratio
# Ratio (0.80, 0.20) means 80% of the data is used for training and 20% for validation
ys.from_yolo_dir(r"/content/train_data")

# %%
ys.info()
# Out:
# {'train': 447,
#  'val': 128,
#  'test': 63,
#  'cls_names': {0, 1, 2, 3, 4, 5, 6},
#  'errors': 0}

# %%
ys.from_yolo_dir(r"/content/train_data",ratio=(0.80,0.20))

# %%
# Save the split dataset to a new directory called "aqa2"
ys.save_split(r"/content/train_data/aqa2")
# Out:
# 100%|██████████| 638/638 [00:01<00:00, 559.08it/s]

# %%
# Define paths for saving the trained model and project files
project = "/content/drive/MyDrive/project/aqa"
dir_path = "/content/drive/MyDrive/project/aqa"

# Train the YOLOv8 model with the split dataset
# Parameters:
# - data: path to the YAML file describing the dataset structure and splits
# - epochs: number of epochs to train the model
# - project: directory where training outputs (logs, weights) will be saved
# - save_dir: directory to save the model weights and logs

model.train(data = "/content/train_data/aqa2/data.yaml", epochs=150,project = project, save_dir=dir_path)
# Out:
# Ultralytics YOLOv8.2.87 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import display,Image

# %%
Image("/content/drive/MyDrive/project/aqa/train22222/val_batch2_pred.jpg")

# %%
Image("/content/drive/MyDrive/project/aqa/train22222/val_batch2_pred.jpg")

# %%
model1=YOLO("/content/drive/MyDrive/project/aqa/train22222/weights/best.pt")

# %%
model1.predict('/content/IMG_2308_jpeg_jpg.rf.7f5bc9634b415d515784dc7ae7a83532.jpg',save=True)
# Out:
# image 1/1 /content/IMG_2308_jpeg_jpg.rf.7f5bc9634b415d515784dc7ae7a83532.jpg: 640x480 1 penguin, 1048.0ms
# Speed: 17.0ms preprocess, 1048.0ms inference, 25.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'fish', 1: 'jellyfish', 2: 'penguin', 3: 'puffin', 4: 'shark', 5: 'starfish', 6: 'stingray'}
#  obb: None
#  orig_img: array([[[201, 242, 211],
#          [199, 240, 209],
#          [196, 235, 203],
#          ...,
#          [ 73,  49,   7],
#          [ 73,  49,   7],
#          [ 72,  48,   6]],
#
#         [[195, 236, 205],
#          [197, 238, 207],
#          [198, 237, 205],
#          ...,
#          [ 73,  49,   7],
#          [ 73,  49,   7],
#          [ 71,  47,   5]],
#
#         [[192, 231, 199],
#          [196, 235, 203],
#          [199, 236, 204],
# ...

# %%
Image("/content/IMG_2308_jpeg_jpg.rf.7f5bc9634b415d515784dc7ae7a83532.jpg")

# %%
display(Image("/content/runs/detect/predict/IMG_2308_jpeg_jpg.rf.7f5bc9634b415d515784dc7ae7a83532.jpg"))

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-f19ab4ca4180> in <cell line: 1>()
# ----> 1 model1.evaluate
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1707             if name in modules:
#    1708                 return modules[name]
# -> 1709         raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#    1710
#    1711     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# AttributeError: 'YOLO' object has no attribute 'evaluate'

# %%
df=ys.get_dataframe()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638 entries, 0 to 637
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   images     638 non-null    object
#  1   labels     638 non-null    object
#  2   annots     638 non-null    object
#  3   cls_names  638 non-null    object
#  4   set        638 non-null    object
#  5   new_set    638 non-null    object
# dtypes: object(6)
# memory usage: 30.0+ KB

# %%
import numpy as np

# %%
df.columns
# Out:
# Index(['images', 'labels', 'annots', 'cls_names', 'set', 'new_set'], dtype='object')

# %%
CL=np.concatenate(df.cls_names.to_numpy())

# %%
import seaborn as sb

# %%
sb.countplot(x=CL)
# Out:
# <Axes: ylabel='count'>

# %%
np.unique(CL,return_counts=True)
# Out:
# (array([          0,           1,           2,           3,           4,           5,           6]),
#  array([333,  52,  71,  66, 176,  59, 124]))

# %%
# From the graph, we can observe that due to the higher number of images in class O, the model is trained more extensively on that class. To ensure accurate predictions for other classes, it is essential to increase the number of images within those classes.

# %% [markdown]
# From the graph, we can observe that due to the higher number of images in class 0, the model is trained more extensively on that class. To ensure accurate predictions for other classes, it is essential to increase the number of images within those classes.

# %%
model1.val()
# Out:
# Ultralytics YOLOv8.2.87 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 4.18MB/s]
# val: Scanning /content/train_data/aqa2/val/labels... 128 images, 0 backgrounds, 0 corrupt: 100%|██████████| 128/128 [00:00<00:00, 1600.70it/s]
# val: New cache created: /content/train_data/aqa2/val/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [01:49<00:00, 13.66s/it]
#                    all        128       1093      0.965       0.96      0.978      0.894
#                   fish         69        706      0.963      0.941      0.971      0.852
#              jellyfish         10         95      0.974      0.979      0.985      0.932
#                penguin         12         92      0.983      0.957      0.986      0.808
#                 puffin         15         67      0.901      0.949      0.957      0.855
# ...

# %% [markdown]
# maps: array([    0.85238,       0.93214,     0.80771,     0.85456,     0.90466,     0.94597,     0.96125])
#
#
#
#
# ---
#
#
# names:{0: 'fish', 1: 'jellyfish', 2: 'penguin', 3: 'puffin', 4: 'shark', 5: 'starfish', 6: 'stingray'}

# %%
Image("/content/drive/MyDrive/project/aqa/train22222/PR_curve.png")

# %%
validation_images="/content/train_data/valid/images"

# %%
results = model1.predict(validation_images, save=True)
# Out:
# image 1/127 /content/train_data/valid/images/IMG_2277_jpeg_jpg.rf.86c72d6192da48d941ffa957f4780665.jpg: 640x480 16 fishs, 525.7ms
# image 2/127 /content/train_data/valid/images/IMG_2278_jpeg_jpg.rf.3c7006d683b0fc62b9b5d84a2868c31c.jpg: 640x480 8 fishs, 427.5ms
# image 3/127 /content/train_data/valid/images/IMG_2279_jpeg_jpg.rf.c93235205522529fc7e9626bf9175cba.jpg: 640x480 30 fishs, 446.0ms
# image 4/127 /content/train_data/valid/images/IMG_2288_jpeg_jpg.rf.18da58173e72084ebd73149bc8914ec1.jpg: 640x480 1 puffin, 437.9ms
# image 5/127 /content/train_data/valid/images/IMG_2297_jpeg_jpg.rf.a7b46f3c112b1c319d824598ee1aafd5.jpg: 640x480 1 puffin, 458.5ms
# image 6/127 /content/train_data/valid/images/IMG_2305_jpeg_jpg.rf.9590ed0a48add800dc5ea8d3f85d3469.jpg: 640x480 1 penguin, 452.2ms
# image 7/127 /content/train_data/valid/images/IMG_2317_jpeg_jpg.rf.f30ebbdde1be950767da30bd3fbc1493.jpg: 640x480 1 penguin, 679.4ms
# ...

# %% [markdown]
# #Potential real-world applications of model
#
# In marine biology for Fish Population Monitoring where The model could automate the process of counting fish in underwater video footage, aiding researchers in studying population dynamics and species diversity.

# %% [markdown]
# #strategies for improving the model’s performance
# 1.Data Augmentation:
#
# Increase Dataset Size: The current dataset is relatively small, acquiring more images can significantly enhance model performance.
# Image Transformations: Apply various transformations to existing images to create new training data
#
#
# 2.Hyperparameter Tuning:
#
# Grid Search: Experiment with different combinations of hyperparameters
